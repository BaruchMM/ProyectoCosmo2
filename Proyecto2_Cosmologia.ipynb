# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas, pylab

# %% [markdown]
# Utilizando datos obtenidos de Class, se variaronlos parámetros $\Omega_B$, $\Omega_{CDM}$, $h$, $\ln(A_s)$, $\Tau_{reio}$ y $n_s$.
# Para observar la importancia de ello, calcularos el módulo de distancia utilizando los valores de la distancia luminosa de Class para cadia variación de parámetros. Con ello, obtenemos las siguientes gráficas.

# %%
## Background variation
fig, axs = plt.subplots(2, 3, sharex=True, sharey=True)
fig.set_dpi(120)
# variation in omega_b
file = np.loadtxt("datos/backc_ontrol.dat")
axs[0, 0].plot(file.T[0],5*np.log10(file.T[6])+25, color='blue', lw=2,label='Control')
file = np.loadtxt("datos/variandoOmegaB/default00_background.dat")
axs[0, 0].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='-0.05')
file = np.loadtxt("datos/variandoOmegaB/default01_background.dat")
axs[0, 0].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='-0.10')
file = np.loadtxt("datos/variandoOmegaB/default02_background.dat")
axs[0, 0].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='-0.15')
file = np.loadtxt("datos/variandoOmegaB/default03_background.dat")
axs[0, 0].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='+0.05')
file = np.loadtxt("datos/variandoOmegaB/default04_background.dat")
axs[0, 0].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='+0.10')
axs[0, 0].set_title("variation in $\Omega_b$")


# variation in $\Omega(CDM)$
file = np.loadtxt("datos/backc_ontrol.dat")
axs[0, 1].plot(file.T[0],5*np.log10(file.T[6])+25, color='blue', lw=2,label='Control')
file = np.loadtxt("datos/VariandoOmegaCDM/default00_background.dat")
axs[0, 1].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='-0.05')
file = np.loadtxt("datos/VariandoOmegaCDM/default01_background.dat")
axs[0, 1].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='-0.10')
file = np.loadtxt("datos/VariandoOmegaCDM/default02_background.dat")
axs[0, 1].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='-0.15')
file = np.loadtxt("datos/VariandoOmegaCDM/default03_background.dat")
axs[0, 1].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='+0.05')
file = np.loadtxt("datos/VariandoOmegaCDM/default04_background.dat")
axs[0, 1].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='+0.10')
axs[0, 1].set_title("variation in $\Omega(CDM)$")
# Variando_h
file = np.loadtxt("datos/backc_ontrol.dat")
axs[0, 2].plot(file.T[0],5*np.log10(file.T[6])+25, color='blue', lw=2,label='Control')
file = np.loadtxt("datos/Variando_h/default00_background.dat")
axs[0, 2].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='-0.05')
file = np.loadtxt("datos/Variando_h/default01_background.dat")
axs[0, 2].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='-0.10')
file = np.loadtxt("datos/Variando_h/default02_background.dat")
axs[0, 2].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='-0.15')
file = np.loadtxt("datos/Variando_h/default03_background.dat")
axs[0, 2].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='+0.05')
file = np.loadtxt("datos/Variando_h/default04_background.dat")
axs[0, 2].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='+0.10')
file = np.loadtxt("datos/Variando_h/default05_background.dat")
axs[0, 2].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='+0.15')
axs[0, 2].set_title("Variando h")

# Variando_lnA_s
file = np.loadtxt("datos/backc_ontrol.dat")
axs[1, 0].plot(file.T[0],5*np.log10(file.T[6])+25, color='blue', lw=2,label='Control')
file = np.loadtxt("datos/Variando_lnA_s/default00_background.dat")
axs[1, 0].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='-0.05')
file = np.loadtxt("datos/Variando_lnA_s/default01_background.dat")
axs[1, 0].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='-0.10')
file = np.loadtxt("datos/Variando_lnA_s/default02_background.dat")
axs[1, 0].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='-0.15')
file = np.loadtxt("datos/Variando_lnA_s/default03_background.dat")
axs[1, 0].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='+0.05')
file = np.loadtxt("datos/Variando_lnA_s/default04_background.dat")
axs[1, 0].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='+0.10')
file = np.loadtxt("datos/Variando_lnA_s/default05_background.dat")
axs[1, 0].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='+0.15')
axs[1, 0].set_title("Variando $ln(A_s)$")

# regular star marker
file = np.loadtxt("datos/backc_ontrol.dat")
axs[1, 1].plot(file.T[0],5*np.log10(file.T[1])+25, color='blue', lw=2,label='Control')
file = np.loadtxt("datos/Variando_Tau_reio/default00_background.dat")
axs[1, 1].plot(file.T[0],5*np.log10(file.T[1])+25, lw=2,label='-0.05')
file = np.loadtxt("datos/Variando_Tau_reio/default01_background.dat")
axs[1, 1].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='-0.10')
file = np.loadtxt("datos/Variando_Tau_reio/default02_background.dat")
axs[1, 1].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='-0.15')
file = np.loadtxt("datos/Variando_Tau_reio/default03_background.dat")
axs[1, 1].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='+0.05')
file = np.loadtxt("datos/Variando_Tau_reio/default04_background.dat")
axs[1, 1].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='+0.10')
file = np.loadtxt("datos/Variando_Tau_reio/default05_background.dat")
axs[1, 1].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='+0.15')
axs[1, 1].set_title("Variando $T$ reio")

# Variando n_s
file = np.loadtxt("datos/backc_ontrol.dat")
axs[1, 2].plot(file.T[0],5*np.log10(file.T[6])+25, color='blue', lw=2,label='Control')
file = np.loadtxt("datos/Variando_n_s/default00_background.dat")
axs[1, 2].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='-0.05')
file = np.loadtxt("datos/Variando_n_s/default01_background.dat")
axs[1, 2].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='-0.10')
file = np.loadtxt("datos/Variando_n_s/default02_background.dat")
axs[1, 2].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='-0.15')
file = np.loadtxt("datos/Variando_n_s/default03_background.dat")
axs[1, 2].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='+0.05')
file = np.loadtxt("datos/Variando_n_s/default04_background.dat")
axs[1, 2].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='+0.10')
file = np.loadtxt("datos/Variando_n_s/default05_background.dat")
axs[1, 2].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='+0.15')
axs[1, 2].set_title("variation in $n_s$")
plt.ylim(35,50)
plt.xlim(0,2)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\baruc\AppData\Local\Temp\ipykernel_12752\1168970625.py:6: RuntimeWarning: divide by zero encountered in log10
#   axs[0, 0].plot(file.T[0],5*np.log10(file.T[6])+25, color='blue', lw=2,label='Control')
# C:\Users\baruc\AppData\Local\Temp\ipykernel_12752\1168970625.py:8: RuntimeWarning: divide by zero encountered in log10
#   axs[0, 0].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='-0.05')
# C:\Users\baruc\AppData\Local\Temp\ipykernel_12752\1168970625.py:10: RuntimeWarning: divide by zero encountered in log10
#   axs[0, 0].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='-0.10')
# C:\Users\baruc\AppData\Local\Temp\ipykernel_12752\1168970625.py:12: RuntimeWarning: divide by zero encountered in log10
#   axs[0, 0].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='-0.15')
# C:\Users\baruc\AppData\Local\Temp\ipykernel_12752\1168970625.py:14: RuntimeWarning: divide by zero encountered in log10
#   axs[0, 0].plot(file.T[0],5*np.log10(file.T[6])+25, lw=2,label='+0.05')
# ...

# %% [markdown]
# De lo anterior notamos que hay una mayor variación en el modulo de distancia al variar $\Omega_{CDM}$ y el parámetro de Hubble reducido $h$.
#
# Además, podemos calcular diferentes curvas del espectro de potencias del CDM. Utilizando los datos de Class, en el archivo cl, si graficamos para cada momento multipolar $l$, variando los valores de $\Omega_B$, obtenemos las siguientes curvas.
#
# En la gráfica se muestra la línea azul que es la de control, es decir, que $\Omega_{CDM}$ no tiene ninguna variación. A esta $\Omega_{CDM}$ de control le denominaremos $\Omega_0$

# %%
fig = plt.figure()
fig.set_dpi(120)

file = np.loadtxt("datos/cl_control.dat")
plt.plot(file.T[0],file.T[1]*0.75*10**12, color='blue', lw=2,label='$\Omega_{0}$')
file = np.loadtxt("datos/variandoOmegaB/default00_cl.dat")
plt.plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$+0.0165')
file = np.loadtxt("datos/variandoOmegaB/default01_cl.dat")
plt.plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$+0.011')
file = np.loadtxt("datos/variandoOmegaB/default02_cl.dat")
plt.plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$+0.0055')
file = np.loadtxt("datos/variandoOmegaB/default03_cl.dat")
plt.plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$-0.0055')
file = np.loadtxt("datos/variandoOmegaB/default04_cl.dat")
plt.plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$-0.011')
fileNasa = pandas.read_csv("nasaCL.csv")
plt.plot(fileNasa['l_center'],fileNasa['Power']*0.1,'+', lw=2,label='experimental Data')
plt.xlabel('z')
plt.xscale('log')

plt.ylabel('$\omega_b$')
plt.legend(fontsize=7)
pylab.show()

# %% [markdown]
# Haciendo este análisis para cada varicaciónd de parámetros obtendremos lo siguiente:

# %%
## Background variation

fig, axs = plt.subplots(2, 3, sharex=True, sharey=True)
fig.set_dpi(120)
# variation in omega_b
fileNasa = pandas.read_csv("nasaCL.csv")
axs[0, 0].plot(fileNasa['l_center'],fileNasa['Power']*0.1,'+', lw=2,label='experimental Data')
file = np.loadtxt("datos/cl_control.dat")
axs[0, 0].plot(file.T[0],file.T[1]*0.75*10**12, color='blue', lw=2,label='$\Omega_{0}$')
file = np.loadtxt("datos/variandoOmegaB/default00_cl.dat")
axs[0, 0].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$+0.0165')
file = np.loadtxt("datos/variandoOmegaB/default01_cl.dat")
axs[0, 0].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$+0.011')
file = np.loadtxt("datos/variandoOmegaB/default02_cl.dat")
axs[0, 0].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$+0.0055')
file = np.loadtxt("datos/variandoOmegaB/default03_cl.dat")
axs[0, 0].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$-0.0055')
file = np.loadtxt("datos/variandoOmegaB/default04_cl.dat")
axs[0, 0].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$-0.011')
axs[0, 0].set_title("variation in $\Omega_b$")


# variation in $\Omega(CDM)$
fileNasa = pandas.read_csv("nasaCL.csv")
axs[0, 1].plot(fileNasa['l_center'],fileNasa['Power']*0.1,'+', lw=2,label='experimental Data')
file = np.loadtxt("datos/cl_control.dat")
axs[0, 1].plot(file.T[0],file.T[1]*0.75*10**12, color='blue', lw=2,label='$\Omega_{0}$')
file = np.loadtxt("datos/VariandoOmegaCDM/default00_cl.dat")
axs[0, 1].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$+0.0165')
file = np.loadtxt("datos/VariandoOmegaCDM/default01_cl.dat")
axs[0, 1].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$+0.011')
file = np.loadtxt("datos/VariandoOmegaCDM/default02_cl.dat")
axs[0, 1].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$+0.0055')
file = np.loadtxt("datos/VariandoOmegaCDM/default03_cl.dat")
axs[0, 1].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$-0.0055')
file = np.loadtxt("datos/VariandoOmegaCDM/default04_cl.dat")
axs[0, 1].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$-0.011')
axs[0, 1].set_title("variation in $\Omega(CDM)$")

# Variando_h
fileNasa = pandas.read_csv("nasaCL.csv")
axs[0, 2].plot(fileNasa['l_center'],fileNasa['Power']*0.1,'+', lw=2,label='experimental Data')
file = np.loadtxt("datos/cl_control.dat")
axs[0, 2].plot(file.T[0],file.T[1]*0.75*10**12, color='blue', lw=2,label='$\Omega_{0}$')
file = np.loadtxt("datos/Variando_h/default00_cl.dat")
axs[0, 2].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$+0.0165')
file = np.loadtxt("datos/Variando_h/default01_cl.dat")
axs[0, 2].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$+0.011')
file = np.loadtxt("datos/Variando_h/default02_cl.dat")
axs[0, 2].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$+0.0055')
file = np.loadtxt("datos/Variando_h/default03_cl.dat")
axs[0, 2].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$-0.0055')
file = np.loadtxt("datos/Variando_h/default04_cl.dat")
axs[0, 2].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$-0.011')
axs[0, 2].set_title("Variando h")

# Variando_lnA_s
fileNasa = pandas.read_csv("nasaCL.csv")
axs[1, 0].plot(fileNasa['l_center'],fileNasa['Power']*0.1,'+', lw=2,label='experimental Data')
file = np.loadtxt("datos/cl_control.dat")
axs[1, 0].plot(file.T[0],file.T[1]*0.75*10**12, color='blue', lw=2,label='$\Omega_{0}$')
file = np.loadtxt("datos/Variando_lnA_s/default00_cl.dat")
axs[1, 0].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$+0.0165')
file = np.loadtxt("datos/Variando_lnA_s/default01_cl.dat")
axs[1, 0].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$+0.011')
file = np.loadtxt("datos/Variando_lnA_s/default02_cl.dat")
axs[1, 0].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$+0.0055')
file = np.loadtxt("datos/Variando_lnA_s/default03_cl.dat")
axs[1, 0].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$-0.0055')
file = np.loadtxt("datos/Variando_lnA_s/default04_cl.dat")
axs[1, 0].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$-0.011')
axs[1, 0].set_title("Variando $ln(A_s)$")

# Variando Tau reio
fileNasa = pandas.read_csv("nasaCL.csv")
axs[1, 1].plot(fileNasa['l_center'],fileNasa['Power']*0.1,'+', lw=2,label='experimental Data')
file = np.loadtxt("datos/cl_control.dat")
axs[1, 1].plot(file.T[0],file.T[1]*0.75*10**12, color='blue', lw=2,label='$\Omega_{0}$')
file = np.loadtxt("datos/Variando_Tau_reio/default00_cl.dat")
axs[1, 1].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$+0.0165')
file = np.loadtxt("datos/Variando_Tau_reio/default01_cl.dat")
axs[1, 1].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$+0.011')
file = np.loadtxt("datos/Variando_Tau_reio/default02_cl.dat")
axs[1, 1].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$+0.0055')
file = np.loadtxt("datos/Variando_Tau_reio/default03_cl.dat")
axs[1, 1].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$-0.0055')
file = np.loadtxt("datos/Variando_Tau_reio/default04_cl.dat")
axs[1, 1].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$-0.011')
axs[1, 1].set_title("Variando $T$ reio")

# Variando n_s
fileNasa = pandas.read_csv("nasaCL.csv")
axs[1, 2].plot(fileNasa['l_center'],fileNasa['Power']*0.1,'+', lw=2,label='experimental Data')
file = np.loadtxt("datos/cl_control.dat")
axs[1, 2].plot(file.T[0],file.T[1]*0.75*10**12, color='blue', lw=2,label='$\Omega_{0}$')
file = np.loadtxt("datos/Variando_n_s/default00_cl.dat")
axs[1, 2].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$+0.0165')
file = np.loadtxt("datos/Variando_n_s/default01_cl.dat")
axs[1, 2].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$+0.011')
file = np.loadtxt("datos/Variando_n_s/default02_cl.dat")
axs[1, 2].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$+0.0055')
file = np.loadtxt("datos/Variando_n_s/default03_cl.dat")
axs[1, 2].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$-0.0055')
file = np.loadtxt("datos/Variando_n_s/default04_cl.dat")
axs[1, 2].plot(file.T[0],file.T[1]*0.75*10**12, lw=2,label='$\Omega_{0}$-0.011')

axs[1, 2].set_title("variation in $n_s$")
plt.ylim(0,800)
plt.xscale('log')

plt.show()

# %%
fig = plt.figure()
fig.set_dpi(120)

file = np.loadtxt("datos/pk_control.dat")
plt.plot(file.T[0],file.T[1], color='blue', lw=2,label='$\Omega_{0}$')
file = np.loadtxt("datos/variandoOmegaB/default00_pk.dat")
plt.plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$+0.0165')
file = np.loadtxt("datos/variandoOmegaB/default01_pk.dat")
plt.plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$+0.011')
file = np.loadtxt("datos/variandoOmegaB/default02_pk.dat")
plt.plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$+0.0055')
file = np.loadtxt("datos/variandoOmegaB/default03_pk.dat")
plt.plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$-0.0055')
file = np.loadtxt("datos/variandoOmegaB/default04_pk.dat")
plt.plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$-0.011')
plt.title("variation in $\Omega_b$")
plt.xlabel('z')

plt.xscale('log')
plt.yscale('log')
plt.ylim(0,30000)
plt.xlim(0.0001,1)
plt.xlabel('$P_m(k)[(h^-1Mpc)^3]$')
plt.ylabel('Matter Power Spectrum varying $\omega_b$')
plt.legend(fontsize=7)
pylab.show()
# Out:
# C:\Users\baruc\AppData\Local\Temp\ipykernel_12752\1040696502.py:21: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(0,30000)

# %%
## Background variation

fig, axs = plt.subplots(2, 3, sharex=True, sharey=True)
fig.set_dpi(120)
# variation in omega_b
file = np.loadtxt("datos/pk_control.dat")
axs[0, 0].plot(file.T[0],file.T[1], color='blue', lw=2,label='$\Omega_{0}$')
file = np.loadtxt("datos/variandoOmegaB/default00_pk.dat")
axs[0, 0].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$+0.0165')
file = np.loadtxt("datos/variandoOmegaB/default01_pk.dat")
axs[0, 0].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$+0.011')
file = np.loadtxt("datos/variandoOmegaB/default02_pk.dat")
axs[0, 0].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$+0.0055')
file = np.loadtxt("datos/variandoOmegaB/default03_pk.dat")
axs[0, 0].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$-0.0055')
file = np.loadtxt("datos/variandoOmegaB/default04_pk.dat")
axs[0, 0].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$-0.011')
axs[0, 0].set_title("variation in $\Omega_b$")


# variation in $\Omega(CDM)$
file = np.loadtxt("datos/pk_control.dat")
axs[0, 1].plot(file.T[0],file.T[1], color='blue', lw=2,label='$\Omega_{0}$')
file = np.loadtxt("datos/VariandoOmegaCDM/default00_pk.dat")
axs[0, 1].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$+0.0165')
file = np.loadtxt("datos/VariandoOmegaCDM/default01_pk.dat")
axs[0, 1].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$+0.011')
file = np.loadtxt("datos/VariandoOmegaCDM/default02_pk.dat")
axs[0, 1].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$+0.0055')
file = np.loadtxt("datos/VariandoOmegaCDM/default03_pk.dat")
axs[0, 1].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$-0.0055')
file = np.loadtxt("datos/VariandoOmegaCDM/default04_pk.dat")
axs[0, 1].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$-0.011')
axs[0, 1].set_title("variation in $\Omega(CDM)$")

# Variando_h
# file = np.loadtxt("datos/cl_control.dat")
# axs[0, 2].plot(file.T[0],file.T[1], color='blue', lw=2,label='$\Omega_{0}$')
file = np.loadtxt("datos/Variando_h/default00_pk.dat")
axs[0, 2].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$+0.0165')
file = np.loadtxt("datos/Variando_h/default01_pk.dat")
axs[0, 2].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$+0.011')
file = np.loadtxt("datos/Variando_h/default02_pk.dat")
axs[0, 2].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$+0.0055')
file = np.loadtxt("datos/Variando_h/default03_pk.dat")
axs[0, 2].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$-0.0055')
file = np.loadtxt("datos/Variando_h/default04_pk.dat")
axs[0, 2].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$-0.011')
axs[0, 2].set_title("Variando h")

# Variando_lnA_s
file = np.loadtxt("datos/Variando_lnA_s/default00_pk.dat")
axs[1, 0].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$+0.0165')
file = np.loadtxt("datos/Variando_lnA_s/default01_pk.dat")
axs[1, 0].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$+0.011')
file = np.loadtxt("datos/Variando_lnA_s/default02_pk.dat")
axs[1, 0].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$+0.0055')
file = np.loadtxt("datos/Variando_lnA_s/default03_pk.dat")
axs[1, 0].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$-0.0055')
file = np.loadtxt("datos/Variando_lnA_s/default04_pk.dat")
axs[1, 0].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$-0.011')
axs[1, 0].set_title("Variando $ln(A_s)$")

# Variando Tau reio
file = np.loadtxt("datos/Variando_Tau_reio/default00_pk.dat")
axs[1, 1].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$+0.0165')
file = np.loadtxt("datos/Variando_Tau_reio/default01_pk.dat")
axs[1, 1].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$+0.011')
file = np.loadtxt("datos/Variando_Tau_reio/default02_pk.dat")
axs[1, 1].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$+0.0055')
file = np.loadtxt("datos/Variando_Tau_reio/default03_pk.dat")
axs[1, 1].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$-0.0055')
file = np.loadtxt("datos/Variando_Tau_reio/default04_pk.dat")
axs[1, 1].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$-0.011')
axs[1, 1].set_title("Variando $T$ reio")

# Variando n_s
file = np.loadtxt("datos/Variando_n_s/default00_pk.dat")
axs[1, 2].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$+0.0165')
file = np.loadtxt("datos/Variando_n_s/default01_pk.dat")
axs[1, 2].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$+0.011')
file = np.loadtxt("datos/Variando_n_s/default02_pk.dat")
axs[1, 2].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$+0.0055')
file = np.loadtxt("datos/Variando_n_s/default03_pk.dat")
axs[1, 2].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$-0.0055')
file = np.loadtxt("datos/Variando_n_s/default04_pk.dat")
axs[1, 2].plot(file.T[0],file.T[1], lw=2,label='$\Omega_{0}$-0.011')

axs[1, 2].set_title("variation in $n_s$")
# plt.ylim(0,30000)
# plt.yscale('')
plt.xscale('log')
plt.yscale('log')

plt.show()
